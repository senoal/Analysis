# %%
import pandas as pd

df = pd.read_excel('Rekap_OnlineCourse.xlsx')
df.head(10)
# Out:
#   Rekap Pengumpulan Tugas dan Quiz Bootcamp Data Science  \
# 0                                               NAMA
# 1                                                NaN
# 2                                `ALIMA RASYIDA AMIN
# 3                                Abdul Ghafar Ismail
# 4                          Abdul Ghani Asykur Thoriq
# 5                                        Abdul Gofur
# 6                                           Abdullah
# 7                                   Abdullah Aljabir
# 8                              Abdullah Nashih Ulwan
# 9                        Abdullah Sholahuddin Basyir
#
#                          Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                             Email     Week 1        NaN        NaN
# 1                               NaN      Day 1      Day 2      Day 3
# 2          alimarasyida08@gmail.com          1          1          1
# 3                afasma03@gmail.com          1          1          0
# 4  abdulghaniasykurthoriq@gmail.com          1          1          1
# 5          abdul.createit@gmail.com          1          1          1
# 6      iriandaabdullah546@gmail.com          0          1          1
# 7          abdulahaljabir@gmail.com          0          0          0
# 8         abdullahulwan03@gmail.com          1          1          1
# 9            jijihadullah@gmail.com          1          1          1
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 20  \
# 0        NaN        NaN        NaN        NaN     Week 2  ...         NaN
# 1      Day 4      Day 5     Quiz 1         MP      Day 1  ...       Day 5
# 2          1          1         14          1          0  ...           1
# 3          1          1         14          1          0  ...           0
# 4          1          1          9          1          1  ...           0
# 5          1          1         14          1          1  ...           1
# 6          1          0          8          1          0  ...           0
# 7          0          0          0          0          0  ...           0
# 8          1          1         12          1          1  ...           0
# 9          1          1          3          0          1  ...           1
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 0         NaN         NaN      Week 4         NaN         NaN         NaN
# 1      Quiz 3          MP       Day 1       Day 2       Day 3       Day 4
# 2           0         NaN           1           0           1           0
# 3           8         NaN           1           0           1           1
# 4           0         NaN           1           0           0           0
# 5           2         NaN           1           1           1           1
# 6           0         NaN           0           0           0           0
# 7           0         NaN           0           0           0           0
# 8          26         NaN           1           0           1           1
# 9           0         NaN           1           1           1           1
#
#   Unnamed: 27  Unnamed: 28        Unnamed: 29
# 0         NaN          NaN                NaN
# 1       Day 5  Nilai Akhir  Nilai Akhir > 80%
# 2           1     0.619048                  0
# 3           0     0.628571                  0
# 4           0     0.461905                  0
# 5           1     0.654762                  0
# 6           0     0.216667                  0
# 7           0            0                  0
# 8           1      0.77619                  0
# 9           1     0.264286                  0
#
# [10 rows x 30 columns]

# %%
# Periksa kolom yang mengandung data kosong
df.isnull().sum()
# Out:
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data Science       1
# Unnamed: 1                                                   2
# Unnamed: 2                                                   0
# Unnamed: 3                                                   1
# Unnamed: 4                                                   1
# Unnamed: 5                                                   1
# Unnamed: 6                                                   1
# Unnamed: 7                                                   1
# Unnamed: 8                                                   1
# Unnamed: 9                                                   0
# Unnamed: 10                                                  1
# Unnamed: 11                                                  1
# Unnamed: 12                                                  1
# Unnamed: 13                                                  1
# Unnamed: 14                                                418
# Unnamed: 15                                               1296
# Unnamed: 16                                                  0
# Unnamed: 17                                                  1
# Unnamed: 18                                                  1
# Unnamed: 19                                                  1
# Unnamed: 20                                                  1
# Unnamed: 21                                                  1
# Unnamed: 22                                               1295
# Unnamed: 23                                                  0
# Unnamed: 24                                                  1
# Unnamed: 25                                                  1
# Unnamed: 26                                                  1
# Unnamed: 27                                                  1
# Unnamed: 28                                                  1
# Unnamed: 29                                                  1
# dtype: int64

# %%
# Hapus baris tidak digunakan
data = df.drop([0,1,1296])
data
# Out:
#      Rekap Pengumpulan Tugas dan Quiz Bootcamp Data Science  \
# 2                                   `ALIMA RASYIDA AMIN
# 3                                   Abdul Ghafar Ismail
# 4                             Abdul Ghani Asykur Thoriq
# 5                                           Abdul Gofur
# 6                                              Abdullah
# ...                                                 ...
# 1291                                       zainal umari
# 1292                                    Zaki Al Faridzi
# 1293                              Zanuar Rahmat Saputra
# 1294                                        ZIKRI HAKIM
# 1295                                    ZULKIFLI SAIJAN
#
#                             Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 2             alimarasyida08@gmail.com          1          1          1
# 3                   afasma03@gmail.com          1          1          0
# 4     abdulghaniasykurthoriq@gmail.com          1          1          1
# 5             abdul.createit@gmail.com          1          1          1
# 6         iriandaabdullah546@gmail.com          0          1          1
# ...                                ...        ...        ...        ...
# 1291                 zain3ie@gmail.com          1          1          1
# 1292             zalfaridzi9@gmail.com          0          0          0
# 1293          rahmatzanuar35@gmail.com          1          1          1
# 1294               dzikrihak@gmail.com          0          1          0
# 1295          zulkiflisaijan@gmail.com          1          0          0
#
#      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 20  \
# 2             1          1         14          1          0  ...           1
# 3             1          1         14          1          0  ...           0
# 4             1          1          9          1          1  ...           0
# 5             1          1         14          1          1  ...           1
# 6             1          0          8          1          0  ...           0
# ...         ...        ...        ...        ...        ...  ...         ...
# 1291          1          1         15          1          1  ...           1
# 1292          0          0          0          0          0  ...           0
# 1293          1          1         13          1          1  ...           0
# 1294          1          1         14          0          0  ...           0
# 1295          0          0          0          0          0  ...           0
#
#      Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 2              0         NaN           1           0           1           0
# 3              8         NaN           1           0           1           1
# 4              0         NaN           1           0           0           0
# 5              2         NaN           1           1           1           1
# 6              0         NaN           0           0           0           0
# ...          ...         ...         ...         ...         ...         ...
# 1291          26         NaN           1           1           1           1
# 1292           0         NaN           0           0           0           0
# 1293           0         NaN           0           0           0           0
# 1294           0         NaN           0           0           0           0
# 1295           0         NaN           0           0           0           0
#
#      Unnamed: 27 Unnamed: 28 Unnamed: 29
# 2              1    0.619048           0
# 3              0    0.628571           0
# 4              0    0.461905           0
# 5              1    0.654762           0
# 6              0    0.216667           0
# ...          ...         ...         ...
# 1291           1        0.95           1
# 1292           0           0           0
# 1293           0    0.488095           0
# 1294           0    0.292857           0
# 1295           0   0.0119048           0
#
# [1294 rows x 30 columns]

# %%
# Ubah sebuah kolom menjadi index
data = data.set_index('Rekap Pengumpulan Tugas dan Quiz Bootcamp Data Science')
data.head()
# Out:
#                                                                           Unnamed: 1  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# `ALIMA RASYIDA AMIN                                         alimarasyida08@gmail.com
# Abdul Ghafar Ismail                                               afasma03@gmail.com
# Abdul Ghani Asykur Thoriq                           abdulghaniasykurthoriq@gmail.com
# Abdul Gofur                                                 abdul.createit@gmail.com
# Abdullah                                                iriandaabdullah546@gmail.com
#
#                                                    Unnamed: 2 Unnamed: 3  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# `ALIMA RASYIDA AMIN                                         1          1
# Abdul Ghafar Ismail                                         1          1
# Abdul Ghani Asykur Thoriq                                   1          1
# Abdul Gofur                                                 1          1
# Abdullah                                                    0          1
#
#                                                    Unnamed: 4 Unnamed: 5  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# `ALIMA RASYIDA AMIN                                         1          1
# Abdul Ghafar Ismail                                         0          1
# Abdul Ghani Asykur Thoriq                                   1          1
# Abdul Gofur                                                 1          1
# Abdullah                                                    1          1
#
#                                                    Unnamed: 6 Unnamed: 7  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# `ALIMA RASYIDA AMIN                                         1         14
# Abdul Ghafar Ismail                                         1         14
# Abdul Ghani Asykur Thoriq                                   1          9
# Abdul Gofur                                                 1         14
# Abdullah                                                    0          8
#
#                                                    Unnamed: 8 Unnamed: 9  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# `ALIMA RASYIDA AMIN                                         1          0
# Abdul Ghafar Ismail                                         1          0
# Abdul Ghani Asykur Thoriq                                   1          1
# Abdul Gofur                                                 1          1
# Abdullah                                                    1          0
#
#                                                    Unnamed: 10  ...  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...              ...
# `ALIMA RASYIDA AMIN                                          1  ...
# Abdul Ghafar Ismail                                          1  ...
# Abdul Ghani Asykur Thoriq                                    0  ...
# Abdul Gofur                                                  1  ...
# Abdullah                                                     1  ...
#
#                                                    Unnamed: 20 Unnamed: 21  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# `ALIMA RASYIDA AMIN                                          1           0
# Abdul Ghafar Ismail                                          0           8
# Abdul Ghani Asykur Thoriq                                    0           0
# Abdul Gofur                                                  1           2
# Abdullah                                                     0           0
#
#                                                    Unnamed: 22 Unnamed: 23  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# `ALIMA RASYIDA AMIN                                        NaN           1
# Abdul Ghafar Ismail                                        NaN           1
# Abdul Ghani Asykur Thoriq                                  NaN           1
# Abdul Gofur                                                NaN           1
# Abdullah                                                   NaN           0
#
#                                                    Unnamed: 24 Unnamed: 25  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# `ALIMA RASYIDA AMIN                                          0           1
# Abdul Ghafar Ismail                                          0           1
# Abdul Ghani Asykur Thoriq                                    0           0
# Abdul Gofur                                                  1           1
# Abdullah                                                     0           0
#
#                                                    Unnamed: 26 Unnamed: 27  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# `ALIMA RASYIDA AMIN                                          0           1
# Abdul Ghafar Ismail                                          1           0
# Abdul Ghani Asykur Thoriq                                    0           0
# Abdul Gofur                                                  1           1
# Abdullah                                                     0           0
#
#                                                    Unnamed: 28 Unnamed: 29
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# `ALIMA RASYIDA AMIN                                   0.619048           0
# Abdul Ghafar Ismail                                   0.628571           0
# Abdul Ghani Asykur Thoriq                             0.461905           0
# Abdul Gofur                                           0.654762           0
# Abdullah                                              0.216667           0
#
# [5 rows x 29 columns]

# %%
# Urutkan data berdasarkan = index
data = data.sort_values(by='Rekap Pengumpulan Tugas dan Quiz Bootcamp Data Science')
data.head()
# Out:
#                                                                       Unnamed: 1  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# ACHMAD IQSAN                                              achmad.iqsan@gmail.com
# ADITYA DWI SETIAWAN                                 setiawanadityadwi0@gmail.com
# AFRIZANDY BAYU YUDHISTIRA                                   afrizandyy@gmail.com
# AGUS SARTOMO                                              agus_sartomo@yahoo.com
# AGUS ZULIYANTO                                             zuliyanto89@gmail.com
#
#                                                    Unnamed: 2 Unnamed: 3  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# ACHMAD IQSAN                                                1          1
# ADITYA DWI SETIAWAN                                         1          1
# AFRIZANDY BAYU YUDHISTIRA                                   1          1
# AGUS SARTOMO                                                1          1
# AGUS ZULIYANTO                                              1          1
#
#                                                    Unnamed: 4 Unnamed: 5  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# ACHMAD IQSAN                                                1          1
# ADITYA DWI SETIAWAN                                         1          1
# AFRIZANDY BAYU YUDHISTIRA                                   1          1
# AGUS SARTOMO                                                1          1
# AGUS ZULIYANTO                                              1          1
#
#                                                    Unnamed: 6 Unnamed: 7  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# ACHMAD IQSAN                                                1         14
# ADITYA DWI SETIAWAN                                         1          4
# AFRIZANDY BAYU YUDHISTIRA                                   1          9
# AGUS SARTOMO                                                1         10
# AGUS ZULIYANTO                                              1         14
#
#                                                    Unnamed: 8 Unnamed: 9  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# ACHMAD IQSAN                                                1          1
# ADITYA DWI SETIAWAN                                         1          0
# AFRIZANDY BAYU YUDHISTIRA                                   1          1
# AGUS SARTOMO                                                1          1
# AGUS ZULIYANTO                                              1          1
#
#                                                    Unnamed: 10  ...  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...              ...
# ACHMAD IQSAN                                                 1  ...
# ADITYA DWI SETIAWAN                                          0  ...
# AFRIZANDY BAYU YUDHISTIRA                                    1  ...
# AGUS SARTOMO                                                 1  ...
# AGUS ZULIYANTO                                               1  ...
#
#                                                    Unnamed: 20 Unnamed: 21  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# ACHMAD IQSAN                                                 1          17
# ADITYA DWI SETIAWAN                                          0           0
# AFRIZANDY BAYU YUDHISTIRA                                    1           5
# AGUS SARTOMO                                                 0           0
# AGUS ZULIYANTO                                               1           6
#
#                                                    Unnamed: 22 Unnamed: 23  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# ACHMAD IQSAN                                               NaN           1
# ADITYA DWI SETIAWAN                                        NaN           0
# AFRIZANDY BAYU YUDHISTIRA                                  NaN           1
# AGUS SARTOMO                                               NaN           0
# AGUS ZULIYANTO                                             NaN           1
#
#                                                    Unnamed: 24 Unnamed: 25  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# ACHMAD IQSAN                                                 1           0
# ADITYA DWI SETIAWAN                                          0           0
# AFRIZANDY BAYU YUDHISTIRA                                    1           1
# AGUS SARTOMO                                                 0           0
# AGUS ZULIYANTO                                               1           1
#
#                                                    Unnamed: 26 Unnamed: 27  \
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# ACHMAD IQSAN                                                 0           0
# ADITYA DWI SETIAWAN                                          0           0
# AFRIZANDY BAYU YUDHISTIRA                                    1           1
# AGUS SARTOMO                                                 0           0
# AGUS ZULIYANTO                                               1           1
#
#                                                    Unnamed: 28 Unnamed: 29
# Rekap Pengumpulan Tugas dan Quiz Bootcamp Data ...
# ACHMAD IQSAN                                          0.772619           0
# ADITYA DWI SETIAWAN                                   0.138095           0
# AFRIZANDY BAYU YUDHISTIRA                             0.541667           0
# AGUS SARTOMO                                           0.27381           0
# AGUS ZULIYANTO                                        0.721429           0
#
# [5 rows x 29 columns]

# %%
# Periksa jumlah total peserta
total_peserta = len(data.index)
total_peserta
# Out:
# 1294

# %%
df['Rekap Pengumpulan Tugas dan Quiz Bootcamp Data Science']
# Out:
# 0                            NAMA
# 1                             NaN
# 2             `ALIMA RASYIDA AMIN
# 3             Abdul Ghafar Ismail
# 4       Abdul Ghani Asykur Thoriq
#                   ...
# 1292              Zaki Al Faridzi
# 1293        Zanuar Rahmat Saputra
# 1294                  ZIKRI HAKIM
# 1295              ZULKIFLI SAIJAN
# 1296     JUMLAH YANG MENGUMPULKAN
# Name: Rekap Pengumpulan Tugas dan Quiz Bootcamp Data Science, Length: 1297, dtype: object

# %%
# Buat nilai uang pendaftaran peserta online course
jaminan = 100000

# Buat rumus mencari total biaya terkumpul
total_jaminan = total_peserta * jaminan
total_jaminan
# Out:
# 129400000

# %%
# Cari peserta lulus (lulus = 1, tidak lulus = 0)
jml_peserta_lolos = data['Unnamed: 29'].sum()
jml_peserta_lolos
# Out:
# 154

# %%
# Buat objek peserta lulus
y = jml_peserta_lolos
print(y)
# Buat objek peserta tidak lulus
x = total_peserta - y
print(x)
# Out:
# 154
# 1140

# %%
# Buat objek total uang kembali ke peserta lulus
total_uang_kembali = y * jaminan
money_l = total_uang_kembali
print("Total biaya kembali ke peserta =",money_l)
# Out:
# Total biaya kembali ke peserta = 15400000

# %%
# Buat objek uang tidak kembali ke peserta (income)
income = total_jaminan - money_l
income
# Out:
# 114000000

# %%
# Buat objek persentase jumlah peserta lulus
persentase = (total_uang_kembali/total_jaminan)*100

# ubah objek ke bentuk int
persentase = int(persentase)
print(persentase)
# Buat objek persentase jumlah peserta tidak lulus
persen = 100 - persentase
print(persen)
# Out:
# 11
# 89

# %%
print("_________Data Bersih (Ekspor ke Excel)_________")

# Masukkan data didapatkan ke dalam bentuk datafram
periksa = {
    'jumlah peserta (Orang)' : [total_peserta],
    'Biaya pendaftaran (Rp.)':[jaminan],
    'Total biaya (Rp.)':[total_jaminan],
    'Peserta lulus (Orang)' : [y],
    'Peserta tidak lulus (Orang)':[x],
    'Persentase jumlah peserta lulus (%)':[persen],
    'Persentase jumlah peserta tidak lulus (%)':[persentase],
    'Pendapatan (Rp.)':[income],
    'Biaya kembali ke peserta lulus (Rp.)':[total_uang_kembali]
    }
periksa
# Out:
# _________Data Bersih (Ekspor ke Excel)_________
# {'jumlah peserta (Orang)': [1294],
#  'Biaya pendaftaran (Rp.)': [100000],
#  'Total biaya (Rp.)': [129400000],
#  'Peserta lulus (Orang)': [154],
#  'Peserta tidak lulus (Orang)': [1140],
#  'Persentase jumlah peserta lulus (%)': [89],
#  'Persentase jumlah peserta tidak lulus (%)': [11],
#  'Pendapatan (Rp.)': [114000000],
#  'Biaya kembali ke peserta lulus (Rp.)': [15400000]}

# %%
# Transformasi bentuk dataframe
data = pd.DataFrame.from_dict(periksa).T
data
# Out:
#                                                    0
# jumlah peserta (Orang)                          1294
# Biaya pendaftaran (Rp.)                       100000
# Total biaya (Rp.)                          129400000
# Peserta lulus (Orang)                            154
# Peserta tidak lulus (Orang)                     1140
# Persentase jumlah peserta lulus (%)               89
# Persentase jumlah peserta tidak lulus (%)         11
# Pendapatan (Rp.)                           114000000
# Biaya kembali ke peserta lulus (Rp.)        15400000

# %%
# Simpan data ke format excel
data.to_excel('Analisa Data Kompetisi X.xlsx')  
data
# Out:
#                                                    0
# jumlah peserta (Orang)                          1294
# Biaya pendaftaran (Rp.)                       100000
# Total biaya (Rp.)                          129400000
# Peserta lulus (Orang)                            154
# Peserta tidak lulus (Orang)                     1140
# Persentase jumlah peserta lulus (%)               89
# Persentase jumlah peserta tidak lulus (%)         11
# Pendapatan (Rp.)                           114000000
# Biaya kembali ke peserta lulus (Rp.)        15400000

# %%
# Membuat visualisasi data, import library
import matplotlib.pyplot as plt

# buat keterangan untuk masing-masing data
judul = ['Tidak Lulus', 'Lulus']
# Masukkan jumlah peserta
jumlah = x,y

# Buat judul untuk hasil visualisasi
title = "Data Peserta Akhir \n-Histogram-"
ttl = "Analysis Result (Histogram)"
ttl1 = "Analysis Result (Pie Chart)"
# Buat bar chart
plt.bar(judul, jumlah)

# Masukkan judul
plt.title(title)
# Masukkan nama label untuk masing-masing sumbu
plt.ylabel("jumlah")
plt.xlabel("kategori")
# Simpan hasil visualisasi
plt.savefig(ttl+".png")
# Cetak visualisasi
plt.show()
# Buat label masing-masing data
pieLabels = 'Tidak Lulus', 'Lulus'

# Masukkan data untuk membuat pie chart
populationShare = x, y
figureObject, axesObject = plt.subplots()
# Buat jarak pada pie
explodeTuple = (0.0, 0.1)
# Atur bentuk pie
axesObject.pie(populationShare, explode=explodeTuple,
               labels=pieLabels, autopct='%1.2f%%',
               startangle=90)
# Buat bentuk frame persegi panjang
axesObject.axis('equal')
# Buat judul untuk pie chart
title = 'Data Online Course\nApril 2020'
# Cetak judul
plt.title(title)
# Simpan file pie chart
plt.savefig(ttl1+'.png')
plt.show()
